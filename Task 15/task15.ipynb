# %% [markdown]
# # Iman Noor
# # ByteWise Fellow
#
# # **Data Wrangling: Join, Combine, and Reshape.**
#
# - Data Wrangling is the process of gathering, collecting, and transforming Raw data into another format for better understanding, decision-making, accessing, and analysis in less time.
# - Data Wrangling is also known as `Data Munging`.
#
# # Data Wrangling in Python
#
# ## Data Exploration
#
# In this process, the data is studied, analyzed, and understood by visualizing representations of data.
#
# ## Dealing with Missing Values
#
# Most of the datasets having a vast amount of data contain missing values of NaN. They need to be taken care of by replacing them with mean, mode, the most frequent value of the column, or simply by dropping the row having a NaN value.
#
# ## Reshaping Data
#
# In this process, data is manipulated according to the requirements, where new data can be added or pre-existing data can be modified.
#
# ## Filtering Data
#
# Sometimes datasets are comprised of unwanted rows or columns which are required to be removed or filtered.
#
# ## Other
#
# After dealing with the raw dataset with the above functionalities, we get an efficient dataset as per our requirements. Then, it can be used for a required purpose like data analyzing, machine learning, data visualization, model training, etc.
#
# ## Data Exploration

# %%
# Importing libraries
import pandas as pd
import numpy as np

# %%
data = {'Name': ['Jai', 'Princi', 'Gaurav', 
                 'Anuj', 'Ravi', 'Natasha', 'Riya'],
        'Age': [17, 17, 18, 17, 18, 17, 17],
        'Gender': ['M', 'F', 'M', 'M', 'M', 'F', 'F'],
        'Marks': [90, 76, 'NaN', 74, 65, 'NaN', 71]}
df = pd.DataFrame(data)
df
# Out:
#       Name  Age Gender Marks
# 0      Jai   17      M    90
# 1   Princi   17      F    76
# 2   Gaurav   18      M   NaN
# 3     Anuj   17      M    74
# 4     Ravi   18      M    65
# 5  Natasha   17      F   NaN
# 6     Riya   17      F    71

# %% [markdown]
# ## Dealing with missing values

# %%
# Computing avg
c = avg = 0
for ele in df['Marks']:
    if str(ele).isnumeric():
        c += 1
        avg += ele
avg /=c
# Replacing missing values
df = df.replace(to_replace="NaN", value=avg)
df
# Out:
#       Name  Age Gender  Marks
# 0      Jai   17      M   90.0
# 1   Princi   17      F   76.0
# 2   Gaurav   18      M   75.2
# 3     Anuj   17      M   74.0
# 4     Ravi   18      M   65.0
# 5  Natasha   17      F   75.2
# 6     Riya   17      F   71.0

# %% [markdown]
# ## Data Replacing in Data Wrangling

# %%
df['Gender'] = df['Gender'].map({'M':0, 'F':1}).astype(float)
df
# Out:
#       Name  Age  Gender  Marks
# 0      Jai   17     0.0   90.0
# 1   Princi   17     1.0   76.0
# 2   Gaurav   18     0.0   75.2
# 3     Anuj   17     0.0   74.0
# 4     Ravi   18     0.0   65.0
# 5  Natasha   17     1.0   75.2
# 6     Riya   17     1.0   71.0

# %% [markdown]
# ## Filtering data in Data Wrangling

# %%
df = df[df['Marks']>=75].copy()
df.drop('Age', axis=1, inplace=True)
df
# Out:
#       Name  Gender  Marks
# 0      Jai     0.0   90.0
# 1   Princi     1.0   76.0
# 2   Gaurav     0.0   75.2
# 5  Natasha     1.0   75.2

# %% [markdown]
# ## Data Wrangling  Using Merge Operation
# > **Syntax:** pd.merge( data_frame1,data_frame2, on=”field “)

# %%
info = pd.DataFrame({
    'ID': [101, 102, 103, 104, 105, 106, 
           107, 108, 109, 110],
    'NAME': ['Jagroop', 'Praveen', 'Harjot', 
             'Pooja', 'Rahul', 'Nikita',
             'Saurabh', 'Ayush', 'Dolly', "Mohit"],
    'BRANCH': ['CSE', 'CSE', 'CSE', 'CSE', 'CSE', 
               'CSE', 'CSE', 'CSE', 'CSE', 'CSE']})
info
# Out:
#     ID     NAME BRANCH
# 0  101  Jagroop    CSE
# 1  102  Praveen    CSE
# 2  103   Harjot    CSE
# 3  104    Pooja    CSE
# 4  105    Rahul    CSE
# 5  106   Nikita    CSE
# 6  107  Saurabh    CSE
# 7  108    Ayush    CSE
# 8  109    Dolly    CSE
# 9  110    Mohit    CSE

# %%
fee_status = pd.DataFrame(
    {'ID': [101, 102, 103, 104, 105, 
            106, 107, 108, 109, 110],
     'PENDING': ['5000', '250', 'NIL', 
                 '9000', '15000', 'NIL',
                 '4500', '1800', '250', 'NIL']})
fee_status
# Out:
#     ID PENDING
# 0  101    5000
# 1  102     250
# 2  103     NIL
# 3  104    9000
# 4  105   15000
# 5  106     NIL
# 6  107    4500
# 7  108    1800
# 8  109     250
# 9  110     NIL

# %%
pd.merge(info, fee_status, on='ID')
# Out:
#     ID     NAME BRANCH PENDING
# 0  101  Jagroop    CSE    5000
# 1  102  Praveen    CSE     250
# 2  103   Harjot    CSE     NIL
# 3  104    Pooja    CSE    9000
# 4  105    Rahul    CSE   15000
# 5  106   Nikita    CSE     NIL
# 6  107  Saurabh    CSE    4500
# 7  108    Ayush    CSE    1800
# 8  109    Dolly    CSE     250
# 9  110    Mohit    CSE     NIL

# %% [markdown]
# ## Data Wrangling Using Grouping Method

# %%
car_selling_data = {'Brand': ['Maruti', 'Maruti', 'Maruti', 
                              'Maruti', 'Hyundai', 'Hyundai', 
                              'Toyota', 'Mahindra', 'Mahindra', 
                              'Ford', 'Toyota', 'Ford'],
                    'Year':  [2010, 2011, 2009, 2013, 
                              2010, 2011, 2011, 2010,
                              2013, 2010, 2010, 2011],
                    'Sold': [6, 7, 9, 8, 3, 5, 
                             2, 8, 7, 2, 4, 2]}
df_c = pd.DataFrame(car_selling_data)
df_c
# Out:
#        Brand  Year  Sold
# 0     Maruti  2010     6
# 1     Maruti  2011     7
# 2     Maruti  2009     9
# 3     Maruti  2013     8
# 4    Hyundai  2010     3
# 5    Hyundai  2011     5
# 6     Toyota  2011     2
# 7   Mahindra  2010     8
# 8   Mahindra  2013     7
# 9       Ford  2010     2
# 10    Toyota  2010     4
# 11      Ford  2011     2

# %% [markdown]
# ## Creating Dataframe to use Grouping methods[DATA OF THE YEAR 2010]:

# %%
grouped = df_c.groupby('Year')
grouped.get_group(2010)
# Out:
#        Brand  Year  Sold
# 0     Maruti  2010     6
# 4    Hyundai  2010     3
# 7   Mahindra  2010     8
# 9       Ford  2010     2
# 10    Toyota  2010     4

# %% [markdown]
# ## Creating Two Dataframe For Concatenation

# %%
data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32], 
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
        'Qualification':['Msc', 'MA', 'MCA', 'Phd'],
        'Mobile No': [97, 91, 58, 76]} 
     
data2 = {'Name':['Gaurav', 'Anuj', 'Dhiraj', 'Hitesh'], 
        'Age':[22, 32, 12, 52], 
        'Address':['Allahabad', 'Kannuaj', 'Allahabad', 'Kannuaj'], 
        'Qualification':['MCA', 'Phd', 'Bcom', 'B.hons'],
        'Salary':[1000, 2000, 3000, 4000]} 
df_1 = pd.DataFrame(data1, index=[0,1,2,3])
df_2 = pd.DataFrame(data2, index=[2,3,6,7])
df_1
# Out:
#      Name  Age    Address Qualification  Mobile No
# 0     Jai   27     Nagpur           Msc         97
# 1  Princi   24     Kanpur            MA         91
# 2  Gaurav   22  Allahabad           MCA         58
# 3    Anuj   32    Kannuaj           Phd         76

# %%
df_2
# Out:
#      Name  Age    Address Qualification  Salary
# 2  Gaurav   22  Allahabad           MCA    1000
# 3    Anuj   32    Kannuaj           Phd    2000
# 6  Dhiraj   12  Allahabad          Bcom    3000
# 7  Hitesh   52    Kannuaj        B.hons    4000

# %%
res = pd.concat([df_1, df_2]) # join these dataframes along axis 0
res
# Out:
#      Name  Age    Address Qualification  Mobile No  Salary
# 0     Jai   27     Nagpur           Msc       97.0     NaN
# 1  Princi   24     Kanpur            MA       91.0     NaN
# 2  Gaurav   22  Allahabad           MCA       58.0     NaN
# 3    Anuj   32    Kannuaj           Phd       76.0     NaN
# 2  Gaurav   22  Allahabad           MCA        NaN  1000.0
# 3    Anuj   32    Kannuaj           Phd        NaN  2000.0
# 6  Dhiraj   12  Allahabad          Bcom        NaN  3000.0
# 7  Hitesh   52    Kannuaj        B.hons        NaN  4000.0

# %%
d1 = {
    'Region': ['North', 'North', 'South', 'South', 'East'],
    'Category': ['Electronics', 'Clothing', 'Electronics', 'Clothing', 'Electronics'],
    'Sales': [5000, 3000, 4000, 3500, 6000]
}

d2 = {
    'Region': ['North', 'South', 'East', 'West'],
    'Category': ['Electronics', 'Clothing', 'Furniture', 'Electronics'],
    'Sales': [4500, 3200, 2800, 5200]
}
region_df1 = pd.DataFrame(d1)
region_df2 = pd.DataFrame(d2)
region_df1
# Out:
#   Region     Category  Sales
# 0  North  Electronics   5000
# 1  North     Clothing   3000
# 2  South  Electronics   4000
# 3  South     Clothing   3500
# 4   East  Electronics   6000

# %%
region_df2
# Out:
#   Region     Category  Sales
# 0  North  Electronics   4500
# 1  South     Clothing   3200
# 2   East    Furniture   2800
# 3   West  Electronics   5200

# %%
merged_df = pd.merge(region_df1, region_df2, on=['Region', 'Category'], how='inner')

# Reset index after merge
multi_index_df = merged_df.set_index(['Region', 'Category'])

# Reset index to make 'Region' and 'Category' columns again
multi_index_df = multi_index_df.reset_index()

agg_df = multi_index_df.groupby('Region').agg({'Sales_x': 'sum'}).join(
    multi_index_df.groupby('Category').agg({'Sales_x': 'mean'}), lsuffix='_Total', rsuffix='_Average'
)
agg_df
# Out:
#         Sales_x_Total  Sales_x_Average
# Region
# North            5000              NaN
# South            3500              NaN

# %% [markdown]
# # Top 200 Richest Person in the World Dataset 💰🌍💹

# %%
rich = pd.read_csv('Top_Rich.csv')
rich.head()
# Out:
#    S. No.  Rank                      Name  Age        Country Networth  \
# 0       1     1  Bernard Arnault & family   75         France   $233 B
# 1       2     2                 Elon Musk   52  United States   $195 B
# 2       3     3                Jeff Bezos   60  United States   $194 B
# 3       4     4           Mark Zuckerberg   39  United States   $177 B
# 4       5     5             Larry Ellison   79  United States   $141 B
#
#            Industry
# 0  Fashion & Retail
# 1        Automotive
# 2        Technology
# 3        Technology
# 4        Technology

# %% [markdown]
# # T20 World Cup 2024: Top Teams & Players💥🏏🌍

# %%
runs = pd.read_csv('Most_Runs.csv')
runs.head()
# Out:
#    Position          Team              Player  Matches  Innings  Bat Avg  Runs
# 0         1   AFGHANISTAN  Rahmanullah GURBAZ        8        8    35.12   281
# 1         2         INDIA        Rohit SHARMA        8        8    36.71   257
# 2         3     AUSTRALIA         Travis HEAD        7        7    42.50   255
# 3         4  SOUTH AFRICA     Quinton DE KOCK        9        9    27.00   243
# 4         5   AFGHANISTAN      Ibrahim ZADRAN        8        8    28.87   231

# %% [markdown]
# ## **Q1. Merge two DataFrames on a single key.**

# %%
emp1 = pd.DataFrame({
    'employee_id': [1, 2, 3, 4],
    'name': ['Alice', 'Bob', 'Charlie', 'David'],
    'department': ['HR', 'Marketing', 'Engineering', 'Sales'],
    'salary': [60000, 80000, 70000, 90000]
})
emp2 = pd.DataFrame({
    'employee_id': [2, 3, 5],
    'start_year': [2010, 2015, 2018],
    'experience': ['Senior', 'Mid', 'Junior'],
    'bonus': [5000, 3000, 2000]
})
emp1, emp2
# Out:
# (   employee_id     name   department  salary
#  0            1    Alice           HR   60000
#  1            2      Bob    Marketing   80000
#  2            3  Charlie  Engineering   70000
#  3            4    David        Sales   90000,
#     employee_id  start_year experience  bonus
#  0            2        2010     Senior   5000
#  1            3        2015        Mid   3000
#  2            5        2018     Junior   2000)

# %%
merged_data = pd.merge(emp1, emp2, on=['employee_id'])
merged_data
# Out:
#    employee_id     name   department  salary  start_year experience  bonus
# 0            2      Bob    Marketing   80000        2010     Senior   5000
# 1            3  Charlie  Engineering   70000        2015        Mid   3000

# %% [markdown]
# ## **Q2. Merge two DataFrames on multiple keys.**

# %%
emp_m1 = pd.DataFrame({
    'employee_id': [1, 2, 3, 4],
    'project_id': ['P1', 'P2', 'P3', 'P4'],
    'department': ['HR', 'Marketing', 'Engineering', 'Sales'],
    'project_budget': [100000, 150000, 120000, 180000]
})

emp_m2 = pd.DataFrame({
    'employee_id': [2, 3, 5],
    'project_id': ['P2', 'P3', 'P5'],
    'project_status': ['Completed', 'Ongoing', 'Planned'],
    'project_duration': [12, 8, 10]
})
emp_m1, emp_m2
# Out:
# (   employee_id project_id   department  project_budget
#  0            1         P1           HR          100000
#  1            2         P2    Marketing          150000
#  2            3         P3  Engineering          120000
#  3            4         P4        Sales          180000,
#     employee_id project_id project_status  project_duration
#  0            2         P2      Completed                12
#  1            3         P3        Ongoing                 8
#  2            5         P5        Planned                10)

# %%
merged_data2 = pd.merge(emp_m1, emp_m2, on=['employee_id', 'project_id'])
merged_data2
# Out:
#    employee_id project_id   department  project_budget project_status  \
# 0            2         P2    Marketing          150000      Completed
# 1            3         P3  Engineering          120000        Ongoing
#
#    project_duration
# 0                12
# 1                 8

# %% [markdown]
# ## **Q3. Perform an outer join, inner join, left join, and right join.**

# %%
# Outer join
df_o = pd.merge(emp1, emp2, on='employee_id', how='outer')
df_o
# Out:
#    employee_id     name   department   salary  start_year experience   bonus
# 0            1    Alice           HR  60000.0         NaN        NaN     NaN
# 1            2      Bob    Marketing  80000.0      2010.0     Senior  5000.0
# 2            3  Charlie  Engineering  70000.0      2015.0        Mid  3000.0
# 3            4    David        Sales  90000.0         NaN        NaN     NaN
# 4            5      NaN          NaN      NaN      2018.0     Junior  2000.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Inner join
df_i = pd.merge(emp1, emp2, on='employee_id', how='inner')
df_i
# Out:
#    employee_id     name   department  salary  start_year experience  bonus
# 0            2      Bob    Marketing   80000        2010     Senior   5000
# 1            3  Charlie  Engineering   70000        2015        Mid   3000

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# left join
df_l = pd.merge(emp1, emp2, on='employee_id', how='left')
df_l
# Out:
#    employee_id     name   department  salary  start_year experience   bonus
# 0            1    Alice           HR   60000         NaN        NaN     NaN
# 1            2      Bob    Marketing   80000      2010.0     Senior  5000.0
# 2            3  Charlie  Engineering   70000      2015.0        Mid  3000.0
# 3            4    David        Sales   90000         NaN        NaN     NaN

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Right join
df_r = pd.merge(emp1, emp2, on='employee_id', how='right')
df_r
# Out:
#    employee_id     name   department   salary  start_year experience  bonus
# 0            2      Bob    Marketing  80000.0        2010     Senior   5000
# 1            3  Charlie  Engineering  70000.0        2015        Mid   3000
# 2            5      NaN          NaN      NaN        2018     Junior   2000

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## **Q4. Concatenate two DataFrames along rows.**

# %%
concatenated_df = pd.concat([rich, runs], axis=0)
concatenated_df
# Out:
#     S. No.  Rank                      Name   Age        Country Networth  \
# 0      1.0   1.0  Bernard Arnault & family  75.0         France   $233 B
# 1      2.0   2.0                 Elon Musk  52.0  United States   $195 B
# 2      3.0   3.0                Jeff Bezos  60.0  United States   $194 B
# 3      4.0   4.0           Mark Zuckerberg  39.0  United States   $177 B
# 4      5.0   5.0             Larry Ellison  79.0  United States   $141 B
# ..     ...   ...                       ...   ...            ...      ...
# 10     NaN   NaN                       NaN   NaN            NaN      NaN
# 11     NaN   NaN                       NaN   NaN            NaN      NaN
# 12     NaN   NaN                       NaN   NaN            NaN      NaN
# 13     NaN   NaN                       NaN   NaN            NaN      NaN
# 14     NaN   NaN                       NaN   NaN            NaN      NaN
#
#             Industry  Position          Team          Player  Matches  \
# 0   Fashion & Retail       NaN           NaN             NaN      NaN
# 1         Automotive       NaN           NaN             NaN      NaN
# 2         Technology       NaN           NaN             NaN      NaN
# 3         Technology       NaN           NaN             NaN      NaN
# 4         Technology       NaN           NaN             NaN      NaN
# ..               ...       ...           ...             ...      ...
# 10               NaN      11.0       ENGLAND       Phil SALT      8.0
# 11               NaN      12.0     AUSTRALIA    David WARNER      7.0
# 12               NaN      13.0         INDIA    Rishabh PANT      8.0
# 13               NaN      14.0     AUSTRALIA  Marcus STOINIS      7.0
# 14               NaN      15.0  SOUTH AFRICA    David MILLER      9.0
#
#     Innings  Bat Avg   Runs
# 0       NaN      NaN    NaN
# 1       NaN      NaN    NaN
# 2       NaN      NaN    NaN
# 3       NaN      NaN    NaN
# 4       NaN      NaN    NaN
# ..      ...      ...    ...
# 10      7.0    37.60  188.0
# 11      7.0    29.66  178.0
# 12      8.0    24.42  171.0
# 13      5.0    42.25  169.0
# 14      8.0    28.16  169.0
#
# [215 rows x 14 columns]

# %% [markdown]
# ## **Q5. Concatenate two DataFrames along columns.**

# %%
concatenated_df_1 = pd.concat([rich, runs], axis=1)
concatenated_df_1
# Out:
#      S. No.  Rank                             Name  Age        Country  \
# 0         1     1         Bernard Arnault & family   75         France
# 1         2     2                        Elon Musk   52  United States
# 2         3     3                       Jeff Bezos   60  United States
# 3         4     4                  Mark Zuckerberg   39  United States
# 4         5     5                    Larry Ellison   79  United States
# ..      ...   ...                              ...  ...            ...
# 195     196   195                          Lei Jun   54          China
# 196     197   195                 Georg Schaeffler   59        Germany
# 197     198   195  Marcel Herrmann Telles & family   74         Brazil
# 198     199   199             David Velez & family   42       Colombia
# 199     200   200        Suleiman Kerimov & family   58         Russia
#
#     Networth               Industry  Position          Team  \
# 0     $233 B       Fashion & Retail       1.0   AFGHANISTAN
# 1     $195 B             Automotive       2.0         INDIA
# 2     $194 B             Technology       3.0     AUSTRALIA
# 3     $177 B             Technology       4.0  SOUTH AFRICA
# 4     $141 B             Technology       5.0   AFGHANISTAN
# ..       ...                    ...       ...           ...
# 195  $10.9 B             Technology       NaN           NaN
# 196  $10.9 B             Automotive       NaN           NaN
# 197  $10.9 B        Food & Beverage       NaN           NaN
# 198  $10.8 B  Finance & Investments       NaN           NaN
# 199  $10.7 B  Finance & Investments       NaN           NaN
#
#                  Player  Matches  Innings  Bat Avg   Runs
# 0    Rahmanullah GURBAZ      8.0      8.0    35.12  281.0
# 1          Rohit SHARMA      8.0      8.0    36.71  257.0
# 2           Travis HEAD      7.0      7.0    42.50  255.0
# 3       Quinton DE KOCK      9.0      9.0    27.00  243.0
# 4        Ibrahim ZADRAN      8.0      8.0    28.87  231.0
# ..                  ...      ...      ...      ...    ...
# 195                 NaN      NaN      NaN      NaN    NaN
# 196                 NaN      NaN      NaN      NaN    NaN
# 197                 NaN      NaN      NaN      NaN    NaN
# 198                 NaN      NaN      NaN      NaN    NaN
# 199                 NaN      NaN      NaN      NaN    NaN
#
# [200 rows x 14 columns]

# %% [markdown]
# ## **Q6. Concatenate a list of DataFrames.**

# %%
df_list = [rich, runs]
concat_list = pd.concat(df_list, ignore_index=True)
concat_list
# Out:
#      S. No.  Rank                      Name   Age        Country Networth  \
# 0       1.0   1.0  Bernard Arnault & family  75.0         France   $233 B
# 1       2.0   2.0                 Elon Musk  52.0  United States   $195 B
# 2       3.0   3.0                Jeff Bezos  60.0  United States   $194 B
# 3       4.0   4.0           Mark Zuckerberg  39.0  United States   $177 B
# 4       5.0   5.0             Larry Ellison  79.0  United States   $141 B
# ..      ...   ...                       ...   ...            ...      ...
# 210     NaN   NaN                       NaN   NaN            NaN      NaN
# 211     NaN   NaN                       NaN   NaN            NaN      NaN
# 212     NaN   NaN                       NaN   NaN            NaN      NaN
# 213     NaN   NaN                       NaN   NaN            NaN      NaN
# 214     NaN   NaN                       NaN   NaN            NaN      NaN
#
#              Industry  Position          Team          Player  Matches  \
# 0    Fashion & Retail       NaN           NaN             NaN      NaN
# 1          Automotive       NaN           NaN             NaN      NaN
# 2          Technology       NaN           NaN             NaN      NaN
# 3          Technology       NaN           NaN             NaN      NaN
# 4          Technology       NaN           NaN             NaN      NaN
# ..                ...       ...           ...             ...      ...
# 210               NaN      11.0       ENGLAND       Phil SALT      8.0
# 211               NaN      12.0     AUSTRALIA    David WARNER      7.0
# 212               NaN      13.0         INDIA    Rishabh PANT      8.0
# 213               NaN      14.0     AUSTRALIA  Marcus STOINIS      7.0
# 214               NaN      15.0  SOUTH AFRICA    David MILLER      9.0
#
#      Innings  Bat Avg   Runs
# 0        NaN      NaN    NaN
# 1        NaN      NaN    NaN
# 2        NaN      NaN    NaN
# 3        NaN      NaN    NaN
# 4        NaN      NaN    NaN
# ..       ...      ...    ...
# 210      7.0    37.60  188.0
# 211      7.0    29.66  178.0
# 212      8.0    24.42  171.0
# 213      5.0    42.25  169.0
# 214      8.0    28.16  169.0
#
# [215 rows x 14 columns]

# %% [markdown]
# ## **Q7. Reshape data using the melt function to go from wide to long format.**

# %%
df_long = pd.melt(rich, id_vars=['Rank', 'Name'], var_name='Attribute', value_name='Value')
df_long
# Out:
#      Rank                             Name Attribute                  Value
# 0       1         Bernard Arnault & family    S. No.                      1
# 1       2                        Elon Musk    S. No.                      2
# 2       3                       Jeff Bezos    S. No.                      3
# 3       4                  Mark Zuckerberg    S. No.                      4
# 4       5                    Larry Ellison    S. No.                      5
# ..    ...                              ...       ...                    ...
# 995   195                          Lei Jun  Industry             Technology
# 996   195                 Georg Schaeffler  Industry             Automotive
# 997   195  Marcel Herrmann Telles & family  Industry        Food & Beverage
# 998   199             David Velez & family  Industry  Finance & Investments
# 999   200        Suleiman Kerimov & family  Industry  Finance & Investments
#
# [1000 rows x 4 columns]

# %% [markdown]
# ## **Q8. Create a pivot table to summarize data.**

# %%
rich['Networth'] = rich['Networth'].replace({'\$': '', ' B': ''}, regex=True).astype(float)
pivot_table = pd.pivot_table(rich, values='Networth', index='Industry', aggfunc='mean')
pivot_table
# Out:
#                               Networth
# Industry
# Automotive                   34.860000
# Construction & Engineering   20.900000
# Diversified                  38.606667
# Energy                       21.100000
# Fashion & Retail             38.850000
# Finance & Investments        26.643750
# Food & Beverage              24.413333
# Gambling & Casinos           21.600000
# Healthcare                   18.566667
# Logistics                    30.575000
# Manufacturing                20.437500
# Media & Entertainment        32.766667
# Metals & Mining              23.083333
# Real Estate                  16.787500
# Service                      13.800000
# Sports                       13.700000
# Technology                   43.470000
# Telecom                     102.000000

# %% [markdown]
# ## **Q9. Group data by one or more columns and perform aggregation functions (e.g., sum, mean, count).**

# %%
# Summary
runs.describe()
# Out:
#         Position    Matches    Innings    Bat Avg        Runs
# count  15.000000  15.000000  15.000000  15.000000   15.000000
# mean    8.000000   7.800000   7.400000  34.464667  212.800000
# std     4.472136   0.861892   0.985611   6.572447   35.877171
# min     1.000000   6.000000   5.000000  24.420000  169.000000
# 25%     4.500000   7.000000   7.000000  28.645000  183.000000
# 50%     8.000000   8.000000   8.000000  35.120000  214.000000
# 75%    11.500000   8.000000   8.000000  40.125000  237.000000
# max    15.000000   9.000000   9.000000  43.800000  281.000000

# %%
runs.agg(['sum','mean','count'])
# Out:
#        Position                                               Team  \
# sum       120.0  AFGHANISTANINDIAAUSTRALIASOUTH AFRICAAFGHANIST...
# mean        8.0                                                NaN
# count      15.0                                                 15
#
#                                                   Player  Matches  Innings  \
# sum    Rahmanullah GURBAZRohit SHARMATravis HEADQuint...    117.0    111.0
# mean                                                 NaN      7.8      7.4
# count                                                 15     15.0     15.0
#
#           Bat Avg    Runs
# sum    516.970000  3192.0
# mean    34.464667   212.8
# count   15.000000    15.0

# %%
runs.agg(['max','min','std','var','sem'])
# Out:
#       Position         Team        Player   Matches   Innings    Bat Avg  \
# max  15.000000  WEST INDIES   Travis HEAD  9.000000  9.000000  43.800000
# min   1.000000  AFGHANISTAN  Andries GOUS  6.000000  5.000000  24.420000
# std   4.472136          NaN           NaN  0.861892  0.985611   6.572447
# var  20.000000          NaN           NaN  0.742857  0.971429  43.197055
# sem   1.154701          NaN           NaN  0.222539  0.254484   1.696998
#
#             Runs
# max   281.000000
# min   169.000000
# std    35.877171
# var  1287.171429
# sem     9.263446

# %% [markdown]
# ## **Q10. Apply multiple aggregation functions to grouped data.**

# %%
agg_result = rich.groupby(rich['Name']).Networth.agg(['min','max','sum','mean'])
agg_result
# Out:
#                              min    max    sum   mean
# Name
# Abigail Johnson             29.0   29.0   29.0   29.0
# Alain Wertheimer            36.8   36.8   36.8   36.8
# Alexey Mordashov & family   25.5   25.5   25.5   25.5
# Alice Walton                72.3   72.3   72.3   72.3
# Aliko Dangote               13.4   13.4   13.4   13.4
# ...                          ...    ...    ...    ...
# Warren Buffett             133.0  133.0  133.0  133.0
# Wei Jianjun & family        11.2   11.2   11.2   11.2
# William Ding                33.5   33.5   33.5   33.5
# Zhang Yiming                43.4   43.4   43.4   43.4
# Zhong Shanshan              62.3   62.3   62.3   62.3
#
# [200 rows x 4 columns]

# %% [markdown]
# ## **Q11. Use the groupby function to group data and apply custom functions.**

# %%
def custom_summary(group):
    s = pd.Series({
        'Average Networth': group['Networth'].mean(),
        'Total Networth': group['Networth'].sum(),
        'Number of Individuals': group.shape[0]  # number of rows in each group
    })
    return s

# %%
grouped_data = rich.groupby('Industry').apply(custom_summary)
grouped_data
# Out:
#                             Average Networth  Total Networth  \
# Industry
# Automotive                         34.860000           348.6
# Construction & Engineering         20.900000            20.9
# Diversified                        38.606667           579.1
# Energy                             21.100000           189.9
# Fashion & Retail                   38.850000          1165.5
# Finance & Investments              26.643750           852.6
# Food & Beverage                    24.413333           366.2
# Gambling & Casinos                 21.600000            43.2
# Healthcare                         18.566667           111.4
# Logistics                          30.575000           122.3
# Manufacturing                      20.437500           163.5
# Media & Entertainment              32.766667            98.3
# Metals & Mining                    23.083333           277.0
# Real Estate                        16.787500           134.3
# Service                            13.800000            13.8
# Sports                             13.700000            41.1
# Technology                         43.470000          1738.8
# Telecom                           102.000000           102.0
#
#                             Number of Individuals
# Industry
# Automotive                                   10.0
# Construction & Engineering                    1.0
# Diversified                                  15.0
# Energy                                        9.0
# Fashion & Retail                             30.0
# Finance & Investments                        32.0
# Food & Beverage                              15.0
# Gambling & Casinos                            2.0
# Healthcare                                    6.0
# Logistics                                     4.0
# Manufacturing                                 8.0
# Media & Entertainment                         3.0
# Metals & Mining                              12.0
# Real Estate                                   8.0
# Service                                       1.0
# Sports                                        3.0
# Technology                                   40.0
# Telecom                                       1.0

# %% [markdown]
# # **The End :)**
